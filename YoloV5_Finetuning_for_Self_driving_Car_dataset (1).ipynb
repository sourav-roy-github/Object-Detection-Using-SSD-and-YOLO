# %% [markdown]
# # Finetuning of YoloV5 for the Self-driving car dataset

# %%
# Mount Google drive to downlaod datasets
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import zipfile package to unzip, dataset files
import zipfile

# %%
# path of self-driving car dataset on Gdrive
dataset_zip = "/content/drive/MyDrive/datasets/sd_car_dataset_for_yolo.zip"

# %%
# extract zip files into the local direcory
with zipfile.ZipFile(dataset_zip, 'r') as zip_ref:
  zip_ref.extractall()

# %%
# clone offical repo to download the weights
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10200, done.
# remote: Total 10200 (delta 0), reused 0 (delta 0), pack-reused 10200
# Receiving objects: 100% (10200/10200), 10.47 MiB | 26.09 MiB/s, done.
# Resolving deltas: 100% (7068/7068), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 8.2 MB/s
#      |████████████████████████████████| 145 kB 10.0 MB/s
#      |████████████████████████████████| 178 kB 49.0 MB/s
#      |████████████████████████████████| 1.1 MB 48.0 MB/s
#      |████████████████████████████████| 67 kB 5.8 MB/s
#      |████████████████████████████████| 138 kB 61.1 MB/s
#      |████████████████████████████████| 62 kB 826 kB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
# ...

# %%
# change the working directory
# %cd ..
# Out:
# /content

# %%
# Running the yolo model for fine tuning on the dataset for 60 epochs
# This, generates the weights to be used for the YoloV5 model that can be used for model building and
# hyperparamater tuning 
# !python yolov5/train.py --img 512 --batch 16 --epochs 60 --data sd_car_dataset_for_yolo/data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=sd_car_dataset_for_yolo/data.yaml, hyp=yolov5/data/hyps/hyp.scratch.yaml, epochs=60, batch_size=16, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-141-ge8ef8fb torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %%
# Zip the trained model weights into a folder, so the weights can be used for
# model building and hyper parameter tuning
# !zip -r /content/yolo_after_train.zip /content/yolov5
# Out:
#   adding: content/yolov5/ (stored 0%)
#   adding: content/yolov5/.gitignore (deflated 55%)
#   adding: content/yolov5/requirements.txt (deflated 51%)
#   adding: content/yolov5/tutorial.ipynb (deflated 78%)
#   adding: content/yolov5/export.py (deflated 72%)
#   adding: content/yolov5/train.py (deflated 69%)
#   adding: content/yolov5/data/ (stored 0%)
#   adding: content/yolov5/data/SKU-110K.yaml (deflated 53%)
#   adding: content/yolov5/data/xView.yaml (deflated 58%)
#   adding: content/yolov5/data/hyps/ (stored 0%)
#   adding: content/yolov5/data/hyps/hyp.finetune.yaml (deflated 44%)
#   adding: content/yolov5/data/hyps/hyp.finetune_objects365.yaml (deflated 37%)
#   adding: content/yolov5/data/hyps/hyp.scratch-med.yaml (deflated 53%)
#   adding: content/yolov5/data/hyps/hyp.scratch-low.yaml (deflated 54%)
#   adding: content/yolov5/data/hyps/hyp.scratch.yaml (deflated 54%)
#   adding: content/yolov5/data/hyps/hyp.scratch-high.yaml (deflated 53%)
# ...

# %%
# download the zip file with the trained model weighst locally
from google.colab import files
files.download("/content/yolo_after_train.zip")
